# %%
from google.colab import drive
import os
import random
from PIL import Image
import matplotlib.pyplot as plt
import yaml
# !pip install ultralytics -q
from ultralytics import YOLO
import torch

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/MyDrive/training_data.zip" -d "/content/aircraft_data"

# %%
class_names = [
    "A10", "A400M", "AG600", "AH64", "An124", "An22", "An225", "An72",
    "AV8B", "B1", "B2", "B21", "B52", "Be200", "C130", "C17", "C2",
    "C390", "C5", "CH47", "CL415", "E2", "E7", "EF2000", "EMB314",
    "F117", "F14", "F15", "F16", "F18", "F22", "F35", "F4", "H6",
    "Il76", "J10", "J20", "J35", "J36", "J50", "JAS39", "JF17", "JH7",
    "Ka27", "Ka52", "KAAN", "KC135", "KF21", "KJ600", "Mi24", "Mi26",
    "Mi28", "Mi8", "Mig29", "Mig31", "Mirage2000", "MQ9", "P3",
    "Rafale", "RQ4", "SR71", "Su24", "Su25", "Su34", "Su57", "TB001",
    "TB2", "Tornado", "Tu160", "Tu22M", "Tu95", "U2", "UH60", "US2",
    "V22", "V280", "Vulcan", "WZ10", "WZ7", "WZ9", "XB70", "Y20",
    "YF23", "Z10", "Z19"
]

data_config = {
    'train': '/content/aircraft_data/training_data/images/train',
    'val': '/content/aircraft_data/training_data/images/val',
    'nc': len(class_names),
    'names': class_names
}

yaml_file_path = '/content/aircraft_config.yaml'

with open(yaml_file_path, 'w') as file:
    yaml.dump(data_config, file, default_flow_style=False, sort_keys=False)

print(f"✅ YAML file created successfully at: {yaml_file_path}")
print("\n--- File Content ---")
with open(yaml_file_path, 'r') as file:
    print(file.read())
# Out:
# ✅ YAML file created successfully at: /content/aircraft_config.yaml
#
# --- File Content ---
# train: /content/aircraft_data/training_data/images/train
# val: /content/aircraft_data/training_data/images/val
# nc: 85
# names:
# - A10
# - A400M
# - AG600
# - AH64
# - An124
# - An22
# - An225
# - An72
# - AV8B
# - B1
# - B2
# - B21
# - B52
# - Be200
# - C130
# - C17
# - C2
# - C390
# - C5
# - CH47
# - CL415
# - E2
# - E7
# - EF2000
# - EMB314
# - F117
# - F14
# - F15
# - F16
# - F18
# - F22
# - F35
# - F4
# - H6
# - Il76
# - J10
# - J20
# - J35
# - J36
# - J50
# - JAS39
# - JF17
# - JH7
# - Ka27
# - Ka52
# - KAAN
# - KC135
# - KF21
# - KJ600
# - Mi24
# - Mi26
# - Mi28
# - Mi8
# - Mig29
# - Mig31
# - Mirage2000
# - MQ9
# - P3
# - Rafale
# - RQ4
# - SR71
# - Su24
# - Su25
# - Su34
# - Su57
# - TB001
# - TB2
# - Tornado
# - Tu160
# - Tu22M
# - Tu95
# - U2
# - UH60
# - US2
# - V22
# - V280
# - Vulcan
# - WZ10
# - WZ7
# - WZ9
# - XB70
# - Y20
# - YF23
# - Z10
# - Z19

# %%
hyprm = '/content/drive/MyDrive/best_hyperparameters.yaml'

# %%
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 260MB/s]

# %%
results = model.train(
    data="aircraft_config.yaml",
    cfg=hyprm,
    epochs=20,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=/content/drive/MyDrive/best_hyperparameters.yaml, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=aircraft_config.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 