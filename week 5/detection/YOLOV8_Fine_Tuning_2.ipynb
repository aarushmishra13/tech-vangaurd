# %%
from google.colab import drive
import os
import random
from PIL import Image
import matplotlib.pyplot as plt
import yaml
# !pip install ultralytics -q
from ultralytics import YOLO
import torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 45.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.4 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/MyDrive/training_data.zip" -d "/content/aircraft_data"

# %%
class_names = [
    "A10", "A400M", "AG600", "AH64", "An124", "An22", "An225", "An72",
    "AV8B", "B1", "B2", "B21", "B52", "Be200", "C130", "C17", "C2",
    "C390", "C5", "CH47", "CL415", "E2", "E7", "EF2000", "EMB314",
    "F117", "F14", "F15", "F16", "F18", "F22", "F35", "F4", "H6",
    "Il76", "J10", "J20", "J35", "J36", "J50", "JAS39", "JF17", "JH7",
    "Ka27", "Ka52", "KAAN", "KC135", "KF21", "KJ600", "Mi24", "Mi26",
    "Mi28", "Mi8", "Mig29", "Mig31", "Mirage2000", "MQ9", "P3",
    "Rafale", "RQ4", "SR71", "Su24", "Su25", "Su34", "Su57", "TB001",
    "TB2", "Tornado", "Tu160", "Tu22M", "Tu95", "U2", "UH60", "US2",
    "V22", "V280", "Vulcan", "WZ10", "WZ7", "WZ9", "XB70", "Y20",
    "YF23", "Z10", "Z19"
]

data_config = {
    'train': '/content/aircraft_data/training_data/images/train',
    'val': '/content/aircraft_data/training_data/images/val',
    'nc': len(class_names),
    'names': class_names
}

yaml_file_path = '/content/aircraft_config.yaml'

with open(yaml_file_path, 'w') as file:
    yaml.dump(data_config, file, default_flow_style=False, sort_keys=False)

print(f"✅ YAML file created successfully at: {yaml_file_path}")
print("\n--- File Content ---")
with open(yaml_file_path, 'r') as file:
    print(file.read())
# Out:
# ✅ YAML file created successfully at: /content/aircraft_config.yaml
#
# --- File Content ---
# train: /content/aircraft_data/training_data/images/train
# val: /content/aircraft_data/training_data/images/val
# nc: 85
# names:
# - A10
# - A400M
# - AG600
# - AH64
# - An124
# - An22
# - An225
# - An72
# - AV8B
# - B1
# - B2
# - B21
# - B52
# - Be200
# - C130
# - C17
# - C2
# - C390
# - C5
# - CH47
# - CL415
# - E2
# - E7
# - EF2000
# - EMB314
# - F117
# - F14
# - F15
# - F16
# - F18
# - F22
# - F35
# - F4
# - H6
# - Il76
# - J10
# - J20
# - J35
# - J36
# - J50
# - JAS39
# - JF17
# - JH7
# - Ka27
# - Ka52
# - KAAN
# - KC135
# - KF21
# - KJ600
# - Mi24
# - Mi26
# - Mi28
# - Mi8
# - Mig29
# - Mig31
# - Mirage2000
# - MQ9
# - P3
# - Rafale
# - RQ4
# - SR71
# - Su24
# - Su25
# - Su34
# - Su57
# - TB001
# - TB2
# - Tornado
# - Tu160
# - Tu22M
# - Tu95
# - U2
# - UH60
# - US2
# - V22
# - V280
# - Vulcan
# - WZ10
# - WZ7
# - WZ9
# - XB70
# - Y20
# - YF23
# - Z10
# - Z19

# %%
# !cp -r /content/drive/MyDrive/runs /content/

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

results = model.train(
    data='/content/aircraft_config.yaml',
    epochs=20,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content
/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 127/127 [02:08<00:00,  1.01s/it]
#                    all       4043       7232      0.436      0.378      0.372      0.317
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20       4.3G     0.6631      1.708     0.9826         35        640: 100%|██████████| 1011/1011 [12:09<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 127/127 [01:34<00:00,  1.35it/s]
#                    all       4043       7232      0.417      0.386      0.372      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20       4.3G     0.6499      1.622     0.9745         33        640: 100%|██████████| 1011/1011 [15:03<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 127/127 [01:35<00:00,  1.33it/s]
#                    all       4043       7232      0.451      0.372      0.377      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20       4.3G     0.6403      1.583     0.9716         15        640: 100%|██████████| 1011/1011 [13:36<00:00,  1.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 127/127 [02:18<00:00,  1.09s/it]
#                    all       4043       7232      0.484      0.378      0.399      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20       4.3G     0.6503      1.582     0.9784         22        640:   2%|▏         | 21/1011 [00:17<13:33,  1.22it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-8-3619868534.py in <cell line: 0>()
#       1 model = YOLO('/content/runs/detect/train/weights/best.pt')
#       2
# ----> 3 results = model.train(
#       4     data='/content/aircraft_config.yaml',
#       5     epochs=20,
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     797
#     798         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799         self.trainer.train()
#     800         # Update model and cfg after training
#     801         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in train(self)
#     225
#     226         else:
# --> 227             self._do_train(world_size)
#     228
#     229     def _setup_scheduler(self):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     386                 pbar = TQDM(enumerate(self.train_loader), total=nb)
#     387             self.tloss = None
# --> 388             for i, batch in pbar:
#     389                 self.run_callbacks("on_train_batch_start")
#     390                 # Warmup
#
# /usr/local/lib/python3.11/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/build.py in __iter__(self)
#      65         """Create an iterator that yields indefinitely from the underlying iterator."""
#      66         for _ in range(len(self)):
# ---> 67             yield next(self.iterator)
#      68
#      69     def __del__(self):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1456
#    1457             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458             idx, data = self._get_data()
#    1459             self._tasks_outstanding -= 1
#    1460             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1408         elif self._pin_memory:
#    1409             while self._pin_memory_thread.is_alive():
# -> 1410                 success, data = self._try_get_data()
#    1411                 if success:
#    1412                     return data
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1249         #   (bool: whether successfully get data, any: data if successful else None)
#    1250         try:
# -> 1251             data = self._data_queue.get(timeout=timeout)
#    1252             return (True, data)
#    1253         except Exception as e:
#
# /usr/lib/python3.11/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     329             else:
#     330                 if timeout > 0:
# --> 331                     gotit = waiter.acquire(True, timeout)
#     332                 else:
#     333                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# !mkdir -p /content/drive/MyDrive/YOLO_Aircraft_Project/
# !cp -r /content/runs /content/drive/MyDrive/YOLO_Aircraft_Project/
